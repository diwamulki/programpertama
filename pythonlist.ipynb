# %%
list_kosong = []

# %%
list_buah = ["Pisang","Apel","Melon","Durian"]

# %%
list_campuran = ["Nasi",200,1000,5000,"Ikan",True,False]

# %%
print ('list_kosong', list_kosong)
# Out:
# list_kosong []

# %%
print ("isi list campuran", list_campuran)
# Out:
# isi list campuran ['Nasi', 200, 1000, 5000, 'Ikan', True, False]

# %%
print(list_buah[0])
# Out:
# Pisang

# %%
print(list_buah[2])
# Out:
# Melon

# %%
print(list_buah[3])
# Out:
# Durian

# %%
print(list_buah[3])
# Out:
# Durian

# %%
print(list_buah[-1])
# Out:
# Durian

# %%
print(list_buah[0:1])
# Out:
# ['Pisang']

# %%
print(list_buah[0:2])
# Out:
# ['Pisang', 'Apel']

# %%
print(list_buah[1:3])
# Out:
# ['Apel', 'Melon']

# %%
print(list_buah[2:3])
# Out:
# ['Melon']

# %%
print(list_buah[0:1:2])
# Out:
# ['Pisang']

# %%
print(list_buah[0:-1])
# Out:
# ['Pisang', 'Apel', 'Melon']

# %%
print(list_buah[1:])
# Out:
# ['Apel', 'Melon', 'Durian']

# %%
print(list_buah)
# Out:
# ['Pisang', 'Apel', 'Melon', 'Durian']

# %%
print (list_buah)
# Out:
# ['Pisang', 'Apel', 'Melon', 'Durian']

# %%
a = [1,2,3]
b =["a"]
c =[True, "b",False]

# %%
listbaru = a+b+c

# %%
print(listbaru)
# Out:
# [1, 2, 3, 'a', True, 'b', False]

# %%
print(list_buah)
# Out:
# ['Pisang', 'Apel', 'Melon', 'Durian']

# %%
list_buah.reverse()
